# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('weight-height.csv')
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
plt.hist(df['Height'],bins=40)
# Out:
# (array([  3.,   2.,  10.,   8.,  30.,  36.,  57.,  95., 126., 196., 272.,
#         332., 415., 455., 482., 554., 540., 577., 517., 562., 551., 557.,
#         559., 500., 491., 400., 390., 331., 300., 210., 136., 119.,  75.,
#          45.,  24.,  19.,  15.,   4.,   1.,   4.]),
#  array([54.26313333, 54.88152355, 55.49991378, 56.118304  , 56.73669423,
#         57.35508445, 57.97347468, 58.5918649 , 59.21025513, 59.82864535,
#         60.44703558, 61.06542581, 61.68381603, 62.30220626, 62.92059648,
#         63.53898671, 64.15737693, 64.77576716, 65.39415738, 66.01254761,
#         66.63093784, 67.24932806, 67.86771829, 68.48610851, 69.10449874,
#         69.72288896, 70.34127919, 70.95966941, 71.57805964, 72.19644987,
#         72.81484009, 73.43323032, 74.05162054, 74.67001077, 75.28840099,
#         75.90679122, 76.52518144, 77.14357167, 77.7619619 , 78.38035212,
#         78.99874235]),
#  <BarContainer object of 40 artists>)

# %%
plt.hexbin(df['Weight'],df['Height'])

# %%
new_df=df.loc[df.Gender=='Male',:]

# %%
new_df
# Out:
#      Gender     Height      Weight
# 0      Male  73.847017  241.893563
# 1      Male  68.781904  162.310473
# 2      Male  74.110105  212.740856
# 3      Male  71.730978  220.042470
# 4      Male  69.881796  206.349801
# ...     ...        ...         ...
# 4995   Male  68.860062  177.131052
# 4996   Male  68.973423  159.285228
# 4997   Male  67.013795  199.195400
# 4998   Male  71.557718  185.905909
# 4999   Male  70.351880  198.903012
#
# [5000 rows x 3 columns]

# %%
plt.hist(new_df['Weight'],bins=30)
# Out:
# (array([  2.,   3.,   5.,   9.,  22.,  38.,  70., 101., 172., 246., 344.,
#         414., 472., 511., 514., 507., 441., 371., 285., 182., 118.,  80.,
#          50.,  13.,  15.,   4.,   8.,   2.,   0.,   1.]),
#  array([112.90293945, 118.13916475, 123.37539005, 128.61161535,
#         133.84784066, 139.08406596, 144.32029126, 149.55651656,
#         154.79274186, 160.02896717, 165.26519247, 170.50141777,
#         175.73764307, 180.97386837, 186.21009367, 191.44631898,
#         196.68254428, 201.91876958, 207.15499488, 212.39122018,
#         217.62744549, 222.86367079, 228.09989609, 233.33612139,
#         238.57234669, 243.808572  , 249.0447973 , 254.2810226 ,
#         259.5172479 , 264.7534732 , 269.98969851]),
#  <BarContainer object of 30 artists>)

# %%
sns.distplot(new_df['Weight'])
# Out:
# c:\users\91832\appdata\local\programs\python\python38\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.jointplot(new_df['Height'],new_df['Weight'],kind='hex')
sns.jointplot(f['Height'],f['Weight'],kind='hex')
# Out:
# c:\users\91832\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\91832\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
f=df.loc[df.Gender=='Female',:]
f
# Out:
#       Gender     Height      Weight
# 5000  Female  58.910732  102.088326
# 5001  Female  65.230013  141.305823
# 5002  Female  63.369004  131.041403
# 5003  Female  64.479997  128.171511
# 5004  Female  61.793096  129.781407
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [5000 rows x 3 columns]

# %%
sns.jointplot(f['Height'],f['Weight'],kind='hex')
# Out:
# c:\users\91832\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(df['Height'],df['Weight'],hue=df['Gender'],kind='scatter')
# Out:
# c:\users\91832\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(df['Height'],df['Weight'],hue=df['Gender'],kind='kde')
# Out:
# c:\users\91832\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.scatter(df['Height',df['Weight'],c=df['Gender'],cmap='magma')
plt.colorbar()
# Out:
#   File "<ipython-input-24-8784972369a8>", line 1
#     plt.scatter(df['Height',df['Weight'],c=df['Gender'],cmap='magma')
#                                           ^
# SyntaxError: invalid syntax

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]
