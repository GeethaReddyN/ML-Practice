# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('used_cars_data.csv',nrows=10000)
df.head()
# Out:
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  ZACNJABB5KPJ92081      35.1 in  NaN        NaN        NaN  SUV / Crossover
# 1  SALCJ2FX1LH858117      38.1 in  NaN        NaN        NaN  SUV / Crossover
# 2  JF1VA2M67G9829723      35.4 in  NaN        NaN        NaN            Sedan
# 3  SALRR2RV0L2433391      37.6 in  NaN        NaN        NaN  SUV / Crossover
# 4  SALCJ2FXXLH862327      38.1 in  NaN        NaN        NaN  SUV / Crossover
#
#   cabin      city  city_fuel_economy  combine_fuel_economy  ...  transmission  \
# 0   NaN   Bayamon                NaN                   NaN  ...             A
# 1   NaN  San Juan                NaN                   NaN  ...             A
# 2   NaN  Guaynabo               17.0                   NaN  ...             M
# 3   NaN  San Juan                NaN                   NaN  ...             A
# 4   NaN  San Juan                NaN                   NaN  ...             A
#
# ...

# %%
df.isna().sum()
# Out:
# vin                        0
# back_legroom             517
# bed                     9931
# bed_height              9307
# bed_length              9307
#                         ...
# wheel_system             465
# wheel_system_display     465
# wheelbase                517
# width                    517
# year                       0
# Length: 66, dtype: int64

# %%
df.columns
# Out:
# Index(['vin', 'back_legroom', 'bed', 'bed_height', 'bed_length', 'body_type',
#        'cabin', 'city', 'city_fuel_economy', 'combine_fuel_economy',
#        'daysonmarket', 'dealer_zip', 'description', 'engine_cylinders',
#        'engine_displacement', 'engine_type', 'exterior_color', 'fleet',
#        'frame_damaged', 'franchise_dealer', 'franchise_make', 'front_legroom',
#        'fuel_tank_volume', 'fuel_type', 'has_accidents', 'height',
#        'highway_fuel_economy', 'horsepower', 'interior_color', 'isCab',
#        'is_certified', 'is_cpo', 'is_new', 'is_oemcpo', 'latitude', 'length',
#        'listed_date', 'listing_color', 'listing_id', 'longitude',
#        'main_picture_url', 'major_options', 'make_name', 'maximum_seating',
#        'mileage', 'model_name', 'owner_count', 'power', 'price', 'salvage',
#        'savings_amount', 'seller_rating', 'sp_id', 'sp_name', 'theft_title',
#        'torque', 'transmission', 'transmission_display', 'trimId', 'trim_name',
# ...

# %%
df.describe()
# Out:
#        city_fuel_economy  combine_fuel_economy  daysonmarket    dealer_zip  \
# count        8327.000000                   0.0  10000.000000  10000.000000
# mean           21.776870                   NaN     74.390500  14092.613300
# std             8.037097                   NaN    104.921508  13807.450059
# min            10.000000                   NaN      0.000000    922.000000
# 25%            18.000000                   NaN     15.000000   7111.000000
# 50%            21.000000                   NaN     37.000000   8701.000000
# 75%            24.000000                   NaN     76.000000  11706.000000
# max           127.000000                   NaN   2150.000000  49203.000000
#
#        engine_displacement  highway_fuel_economy   horsepower  is_certified  \
# count          9443.000000           8327.000000  9443.000000           0.0
# mean           2811.225246             28.771827   245.103251           NaN
# ...

# %%
df.shape
# Out:
# (10000, 66)

# %%
df.head()
# Out:
#                  vin back_legroom  bed bed_height bed_length        body_type  \
# 0  ZACNJABB5KPJ92081      35.1 in  NaN        NaN        NaN  SUV / Crossover
# 1  SALCJ2FX1LH858117      38.1 in  NaN        NaN        NaN  SUV / Crossover
# 2  JF1VA2M67G9829723      35.4 in  NaN        NaN        NaN            Sedan
# 3  SALRR2RV0L2433391      37.6 in  NaN        NaN        NaN  SUV / Crossover
# 4  SALCJ2FXXLH862327      38.1 in  NaN        NaN        NaN  SUV / Crossover
#
#   cabin      city  city_fuel_economy  combine_fuel_economy  ...  transmission  \
# 0   NaN   Bayamon                NaN                   NaN  ...             A
# 1   NaN  San Juan                NaN                   NaN  ...             A
# 2   NaN  Guaynabo               17.0                   NaN  ...             M
# 3   NaN  San Juan                NaN                   NaN  ...             A
# 4   NaN  San Juan                NaN                   NaN  ...             A
#
# ...

# %%
df.set_index('vin',inplace=True)

# %%
df.head()
# Out:
#                   back_legroom  bed bed_height bed_length        body_type  \
# vin
# ZACNJABB5KPJ92081      35.1 in  NaN        NaN        NaN  SUV / Crossover
# SALCJ2FX1LH858117      38.1 in  NaN        NaN        NaN  SUV / Crossover
# JF1VA2M67G9829723      35.4 in  NaN        NaN        NaN            Sedan
# SALRR2RV0L2433391      37.6 in  NaN        NaN        NaN  SUV / Crossover
# SALCJ2FXXLH862327      38.1 in  NaN        NaN        NaN  SUV / Crossover
#
#                   cabin      city  city_fuel_economy  combine_fuel_economy  \
# vin
# ZACNJABB5KPJ92081   NaN   Bayamon                NaN                   NaN
# SALCJ2FX1LH858117   NaN  San Juan                NaN                   NaN
# JF1VA2M67G9829723   NaN  Guaynabo               17.0                   NaN
# SALRR2RV0L2433391   NaN  San Juan                NaN                   NaN
# SALCJ2FXXLH862327   NaN  San Juan                NaN                   NaN
#
# ...
